# %%
# Import required libraries
import pandas as pd
import numpy as np
from textblob import TextBlob
import yfinance as yf
import time
from datetime import datetime
import dash
from dash import dcc, html
from dash.dependencies import Input, Output
import warnings

warnings.filterwarnings('ignore')

# Load sentiment dataset (replace with your dataset path)
# Download from: https://www.kaggle.com/datasets/kazanova/sentiment140
try:
    data = pd.read_csv('sentiment140.csv', encoding='latin-1', header=None, 
                       names=['target', 'id', 'date', 'flag', 'user', 'text'])
except FileNotFoundError:
    print("Please download the Sentiment140 dataset and update the file path.")
    # Assign an empty DataFrame as fallback
    data = pd.DataFrame(columns=['target', 'id', 'date', 'flag', 'user', 'text'])

# Load NIFTY data
nifty = yf.download('^NSEI', start='2024-01-01', end='2025-05-23', interval='1d')

# Function to analyze sentiment
def get_sentiment(text):
    return TextBlob(text).sentiment.polarity  # Returns value between -1 and 1

# Simulate RBI policy announcements (replace with actual RBI text if available)
rbi_statements = [
    "RBI maintains repo rate at 6.5% to support growth.",
    "Inflation concerns prompt RBI to tighten monetary policy.",
    "RBI introduces measures to stabilize financial markets."
]

# Process sentiment for RBI statements
rbi_sentiments = [get_sentiment(text) for text in rbi_statements]
rbi_df = pd.DataFrame({
    'Statement': rbi_statements,
    'Sentiment': rbi_sentiments,
    'Date': [datetime.now() for _ in rbi_statements]
})

# Simulate real-time tweet stream
def simulate_realtime_tweets(n_tweets=5):
    print("Starting real-time sentiment analysis simulation...")
    sentiments = []
    timestamps = []
    
    for i in range(n_tweets):
        if data.empty:
            print("No sentiment data available.")
            break
        
        tweet = data['text'].sample(1).iloc[0]  # Random tweet from dataset
        sentiment = get_sentiment(tweet)
        sentiments.append(sentiment)
        timestamps.append(datetime.now().strftime('%Y-%m-%d %H:%M:%S'))
        print(f"Tweet {i+1}: {tweet[:50]}..., Sentiment: {sentiment:.2f}")
        time.sleep(1)  # Simulate real-time delay
    
    return pd.DataFrame({'Timestamp': timestamps, 'Sentiment': sentiments})

# Run simulation
tweet_data = simulate_realtime_tweets(n_tweets=5)

# Create Dash app for real-time dashboard
app = dash.Dash(__name__)

app.layout = html.Div([
    html.H1("Real-Time RBI Policy Sentiment Dashboard"),
    dcc.Graph(id='sentiment-graph'),
    dcc.Interval(id='interval-component', interval=5*1000, n_intervals=0)  # Update every 5 seconds
])

@app.callback(
    Output('sentiment-graph', 'figure'),
    [Input('interval-component', 'n_intervals')]
)
def update_graph(n):
    global tweet_data
    new_data = simulate_realtime_tweets(n_tweets=1)
    tweet_data = pd.concat([tweet_data, new_data], ignore_index=True)
    
    # Plot sentiment over time
    fig = {
        'data': [
            {'x': tweet_data['Timestamp'], 'y': tweet_data['Sentiment'], 'type': 'line', 'name': 'Tweet Sentiment'},
            {'x': rbi_df['Date'], 'y': rbi_df['Sentiment'], 'type': 'scatter', 'mode': 'markers', 'name': 'RBI Statement Sentiment'}
        ],
        'layout': {
            'title': 'Real-Time Sentiment Analysis of RBI Policy and Tweets',
            'xaxis': {'title': 'Time'},
            'yaxis': {'title': 'Sentiment Score (-1 to 1)'}
        }
    }
    return fig

# Run the app
if __name__ == '__main__':
    print("Starting Dash server... Open http://127.0.0.1:8050/ in your browser.")
    app.run(debug=True)  # Updated: Use app.run() instead of app.run_server()
# Out:
# [*********************100%***********************]  1 of 1 completed
# Please download the Sentiment140 dataset and update the file path.
# Starting real-time sentiment analysis simulation...
# No sentiment data available.
# Starting Dash server... Open http://127.0.0.1:8050/ in your browser.
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
# Starting real-time sentiment analysis simulation...
# No sentiment data available.
# Starting real-time sentiment analysis simulation...
# No sentiment data available.
# Starting real-time sentiment analysis simulation...
# No sentiment data available.
# Starting real-time sentiment analysis simulation...
# No sentiment data available.
# Starting real-time sentiment analysis simulation...
# No sentiment data available.
# Starting real-time sentiment analysis simulation...
# No sentiment data available.
# Starting real-time sentiment analysis simulation...
# No sentiment data available.
# Starting real-time sentiment analysis simulation...
# No sentiment data available.
# Starting real-time sentiment analysis simulation...
# No sentiment data available.
# Starting real-time sentiment analysis simulation...
# No sentiment data available.
# Starting real-time sentiment analysis simulation...
# No sentiment data available.
# Starting real-time sentiment analysis simulation...
# No sentiment data available.
# Starting real-time sentiment analysis simulation...
# No sentiment data available.
# Starting real-time sentiment analysis simulation...
# No sentiment data available.
# Starting real-time sentiment analysis simulation...
# No sentiment data available.
# Starting real-time sentiment analysis simulation...
# No sentiment data available.
# Starting real-time sentiment analysis simulation...
# No sentiment data available.
# Starting real-time sentiment analysis simulation...
# No sentiment data available.
# Starting real-time sentiment analysis simulation...
# No sentiment data available.
# Starting real-time sentiment analysis simulation...
# No sentiment data available.
# Starting real-time sentiment analysis simulation...
# No sentiment data available.
# Starting real-time sentiment analysis simulation...
# No sentiment data available.
# Starting real-time sentiment analysis simulation...
# No sentiment data available.
# Starting real-time sentiment analysis simulation...
# No sentiment data available.
# Starting real-time sentiment analysis simulation...
# No sentiment data available.
# Starting real-time sentiment analysis simulation...
# No sentiment data available.
# Starting real-time sentiment analysis simulation...
# No sentiment data available.
# Starting real-time sentiment analysis simulation...
# No sentiment data available.
# Starting real-time sentiment analysis simulation...
# No sentiment data available.
# Starting real-time sentiment analysis simulation...
# No sentiment data available.
# Starting real-time sentiment analysis simulation...
# No sentiment data available.
# Starting real-time sentiment analysis simulation...
# No sentiment data available.
# Starting real-time sentiment analysis simulation...
# No sentiment data available.
# Starting real-time sentiment analysis simulation...
# No sentiment data available.
# Starting real-time sentiment analysis simulation...
# No sentiment data available.
# Starting real-time sentiment analysis simulation...
# Tweet 1: is getting dressed for a scrumptious dinner with h..., Sentiment: 1.00
# Starting real-time sentiment analysis simulation...
# Tweet 1: LAST DAY OF SCHOOL!!!!!!!!!!!!!!!!!!................., Sentiment: 0.00

# %%
# Import required libraries
import pandas as pd
import numpy as np
from textblob import TextBlob
import yfinance as yf
import time
from datetime import datetime
import dash
from dash import dcc, html
from dash.dependencies import Input, Output
import warnings

warnings.filterwarnings('ignore')

# Load sentiment dataset (using your provided file path)
dataset_path = r"C:\Users\hp\Downloads\archive (9)\training.1600000.processed.noemoticon.csv"

try:
    data = pd.read_csv(dataset_path, encoding='latin-1', header=None, 
                       names=['target', 'id', 'date', 'flag', 'user', 'text'])
    print("Dataset loaded successfully!")
except FileNotFoundError:
    print(f"File not found: {dataset_path}. Please verify the path.")
    # Assign an empty DataFrame as fallback
    data = pd.DataFrame(columns=['target', 'id', 'date', 'flag', 'user', 'text'])

# Load NIFTY data
nifty = yf.download('^NSEI', start='2024-01-01', end='2025-05-23', interval='1d')

# Function to analyze sentiment
def get_sentiment(text):
    return TextBlob(text).sentiment.polarity  # Returns value between -1 and 1

# Simulate RBI policy announcements (replace with actual RBI text if available)
rbi_statements = [
    "RBI maintains repo rate at 6.5% to support growth.",
    "Inflation concerns prompt RBI to tighten monetary policy.",
    "RBI introduces measures to stabilize financial markets."
]

# Process sentiment for RBI statements
rbi_sentiments = [get_sentiment(text) for text in rbi_statements]
rbi_df = pd.DataFrame({
    'Statement': rbi_statements,
    'Sentiment': rbi_sentiments,
    'Date': [datetime.now() for _ in rbi_statements]
})

# Simulate real-time tweet stream
def simulate_realtime_tweets(n_tweets=5):
    print("Starting real-time sentiment analysis simulation...")
    sentiments = []
    timestamps = []
    
    for i in range(n_tweets):
        if data.empty:
            print("No sentiment data available.")
            break
        
        tweet = data['text'].sample(1).iloc[0]  # Random tweet from dataset
        sentiment = get_sentiment(tweet)
        sentiments.append(sentiment)
        timestamps.append(datetime.now().strftime('%Y-%m-%d %H:%M:%S'))
        print(f"Tweet {i+1}: {tweet[:50]}..., Sentiment: {sentiment:.2f}")
        time.sleep(1)  # Simulate real-time delay
    
    return pd.DataFrame({'Timestamp': timestamps, 'Sentiment': sentiments})

# Run simulation
tweet_data = simulate_realtime_tweets(n_tweets=5)

# Create Dash app for real-time dashboard
app = dash.Dash(__name__)

app.layout = html.Div([
    html.H1("Real-Time RBI Policy Sentiment Dashboard"),
    dcc.Graph(id='sentiment-graph'),
    dcc.Interval(id='interval-component', interval=5*1000, n_intervals=0)  # Update every 5 seconds
])

@app.callback(
    Output('sentiment-graph', 'figure'),
    [Input('interval-component', 'n_intervals')]
)
def update_graph(n):
    global tweet_data
    new_data = simulate_realtime_tweets(n_tweets=1)
    tweet_data = pd.concat([tweet_data, new_data], ignore_index=True)
    
    # Plot sentiment over time
    fig = {
        'data': [
            {'x': tweet_data['Timestamp'], 'y': tweet_data['Sentiment'], 'type': 'line', 'name': 'Tweet Sentiment'},
            {'x': rbi_df['Date'], 'y': rbi_df['Sentiment'], 'type': 'scatter', 'mode': 'markers', 'name': 'RBI Statement Sentiment'}
        ],
        'layout': {
            'title': 'Real-Time Sentiment Analysis of RBI Policy and Tweets',
            'xaxis': {'title': 'Time'},
            'yaxis': {'title': 'Sentiment Score (-1 to 1)'}
        }
    }
    return fig

# Run the app
if __name__ == '__main__':
    print("Starting Dash server... Open http://127.0.0.1:8050/ in your browser.")
    app.run(debug=True)  # Updated: Use app.run() instead of app.run_server()
# Out:
# [*********************100%***********************]  1 of 1 completed
# Dataset loaded successfully!
# Starting real-time sentiment analysis simulation...
# Tweet 1: watching the very last episode of the hills. so sa..., Sentiment: -0.25
# Tweet 2: hello twitter world! it's a rainy day today..i lov..., Sentiment: 0.62
# Tweet 3: @StevenMcD *ugh* hate it when someon checks in cod..., Sentiment: -0.80
# Tweet 4: this will be the last for today... SCHOOL tomorrow..., Sentiment: 0.00
# Tweet 5: You don't care a bit ..., Sentiment: 0.00
# Starting Dash server... Open http://127.0.0.1:8050/ in your browser.
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
# Starting real-time sentiment analysis simulation...
# Tweet 1: Got the Smoking Loon Pinot Noir for $13.. not that..., Sentiment: 1.00
# Starting real-time sentiment analysis simulation...
# Tweet 1: True to form, Bank Holiday Monday looks like it mi..., Sentiment: 0.17
# Starting real-time sentiment analysis simulation...
# Tweet 1: just got back from working the Wikimedia booth at ..., Sentiment: 0.15
# Starting real-time sentiment analysis simulation...
# Tweet 1: I need to study. GP Articles/Math/Chemistry. GG ..., Sentiment: 0.00
# Starting real-time sentiment analysis simulation...
# Tweet 1: @allieblue I have ONE Vodka Mudshake  Not going to..., Sentiment: 0.00
# Starting real-time sentiment analysis simulation...
# Tweet 1: BACK IN JERSEY!!!!! BACK IN DA OFFICE....BACK 2 WO..., Sentiment: 0.27
# Starting real-time sentiment analysis simulation...
# Tweet 1: @STLPhoto awesome. thanks for sharing. you have ve..., Sentiment: 0.47
# Starting real-time sentiment analysis simulation...
# Tweet 1: I am so hungry! And there is no food for me to ste..., Sentiment: 0.00
# Starting real-time sentiment analysis simulation...
# Tweet 1: @BrooklynDDecker i noticed you still use BD as you..., Sentiment: 0.00
# Starting real-time sentiment analysis simulation...
# Tweet 1: I already signed up for google's wave preview but ..., Sentiment: 0.00
# Starting real-time sentiment analysis simulation...
# Tweet 1: Gooooddddd EVEEEEEEEEEningggg ALL!!  *ok that is a..., Sentiment: 0.10
# Starting real-time sentiment analysis simulation...
# Tweet 1: @JamekaShamae Thank you very much, Jameka! You're ..., Sentiment: 0.65
# Starting real-time sentiment analysis simulation...
# Tweet 1: definately missed my morning workout ..., Sentiment: 0.00
# Starting real-time sentiment analysis simulation...
# Tweet 1: @Gabanact 26 feels terrible.. My joints ache and I..., Sentiment: -1.00
# Starting real-time sentiment analysis simulation...
# Tweet 1: @AnHonestFraud if you get it... I hate you. ..., Sentiment: -0.80
# Starting real-time sentiment analysis simulation...
# Tweet 1: Its hard being @ the store and going passed the ba..., Sentiment: -0.29
# Starting real-time sentiment analysis simulation...
# Tweet 1: revising ict ..., Sentiment: 0.00
# Starting real-time sentiment analysis simulation...
# Tweet 1: @viveksingh I listened to those songs.. they were ..., Sentiment: 0.00
# Starting real-time sentiment analysis simulation...
# Tweet 1: Watching Season 4 of Weeds-- I love netflix... ..., Sentiment: 0.50
# Starting real-time sentiment analysis simulation...
# Tweet 1: sitting at home ..., Sentiment: 0.00
# Starting real-time sentiment analysis simulation...
# Tweet 1: @trevormendham @lintably I was thinking exactly th..., Sentiment: 0.12
# Starting real-time sentiment analysis simulation...
# Tweet 1: Busch Gardens with Hyde tomorrow ! ..., Sentiment: 0.00
# Starting real-time sentiment analysis simulation...
# Tweet 1: Ready for a stress-free day.  Secretly happy that ..., Sentiment: 0.50
# Starting real-time sentiment analysis simulation...
# Tweet 1: Got creeped out. Time to man up Henry. Night every..., Sentiment: 0.23
# Starting real-time sentiment analysis simulation...
# Tweet 1:  i want Van Basten to b the milan manager !!!..., Sentiment: 0.00
# Starting real-time sentiment analysis simulation...
# Tweet 1: Yes!!! My bestest friend in the world @LANIcruz jo..., Sentiment: 0.98
# Starting real-time sentiment analysis simulation...
# Tweet 1: @TessMorris sorry to hear that ..., Sentiment: -0.50
# Starting real-time sentiment analysis simulation...
# Tweet 1: @suffianr okay u hurt me real bad there  [ mgs.. l..., Sentiment: 0.08
# Starting real-time sentiment analysis simulation...
# Tweet 1: @HospitalityMan LOL! That's brilliant  and sooooo ..., Sentiment: 0.75
# Starting real-time sentiment analysis simulation...
# Tweet 1: has heatstroke and is really poorly ..., Sentiment: -0.40
# Starting real-time sentiment analysis simulation...
# Tweet 1: @Cari_Dale R u getting yours?? I'm still not....an..., Sentiment: 0.00
# Starting real-time sentiment analysis simulation...
# Tweet 1: Im sitting on the computer fighting off the flu!!!..., Sentiment: 0.00
# Starting real-time sentiment analysis simulation...
# Tweet 1: Going bowling with Stacee! ..., Sentiment: 0.00
# Starting real-time sentiment analysis simulation...
# Tweet 1: @betterbudgeting @KeepingItRich I'd love to get yo..., Sentiment: 0.50
# Starting real-time sentiment analysis simulation...
# Tweet 1: @RagingBitch - what can I say, you have excellent ..., Sentiment: 0.85
# Starting real-time sentiment analysis simulation...
# Tweet 1: @dommerghz pink, Gordon Ramsay etc. I'm going CSI...., Sentiment: -0.10
# Starting real-time sentiment analysis simulation...
# Tweet 1: is trying to study geography, but too sleepyy. Its..., Sentiment: 0.50
# Starting real-time sentiment analysis simulation...
# Tweet 1: @michaelmknight the best in ages! ..., Sentiment: 1.00
# Starting real-time sentiment analysis simulation...
# Tweet 1: @jestdempsey Fleetwood Mac canceled at the last mi..., Sentiment: 0.03
# Starting real-time sentiment analysis simulation...
# Tweet 1: not feeling well ..., Sentiment: 0.00
# Starting real-time sentiment analysis simulation...
# Tweet 1: @Pinkaroonie  =-0 I know this now I didnt then.And..., Sentiment: 0.00
# Starting real-time sentiment analysis simulation...
# Tweet 1: ahh- i feel nauseated. -brainwave- AH THAT CAN BE ..., Sentiment: -0.25
# Starting real-time sentiment analysis simulation...
# Tweet 1: @officialTila aww but i didn't get a kiss ..., Sentiment: 0.30
# Starting real-time sentiment analysis simulation...
# Tweet 1: @Loisfxckinhot well im gettin off the laptop so te..., Sentiment: 0.00
# Starting real-time sentiment analysis simulation...
# Tweet 1: So someone has hacked my main computer, put a pass..., Sentiment: 0.08
# Starting real-time sentiment analysis simulation...
# Tweet 1: @ShazGV awhhhh no fun  i wanted to be an honorary ..., Sentiment: -0.15
# Starting real-time sentiment analysis simulation...
# Tweet 1: @MerlottesBar *txt* I hope that's what it is. Caus..., Sentiment: 0.00
# Starting real-time sentiment analysis simulation...
# Tweet 1: @shaunhey Haha, woo Friday and only 2 more half da..., Sentiment: 0.13
# Starting real-time sentiment analysis simulation...
# Tweet 1: Nice time visiting with family, realized I missed ..., Sentiment: 0.55
# Starting real-time sentiment analysis simulation...
# Tweet 1: i'm soo tired and i don't know why ..., Sentiment: -0.40
# Starting real-time sentiment analysis simulation...
# Tweet 1: I luv it!  LastFM love/twitter mashup http://lastf..., Sentiment: 0.00
# Starting real-time sentiment analysis simulation...
# Tweet 1: still workin on those fuckin vectors.. ..., Sentiment: 0.00
# Starting real-time sentiment analysis simulation...
# Tweet 1: i wanna get rockband just so i can get the new bea..., Sentiment: -0.13
# Starting real-time sentiment analysis simulation...
# Tweet 1: HEY CHEYCHEY!!!!!!  omg i LOVE your picture!!! @ch..., Sentiment: 0.98
# Starting real-time sentiment analysis simulation...
# Tweet 1: Started following QueenRania for a change ..., Sentiment: 0.00
# Starting real-time sentiment analysis simulation...
# Tweet 1: half my bedroom is outta power. thanks rain ..., Sentiment: 0.02
# Starting real-time sentiment analysis simulation...
# Tweet 1: @planningforever LOL no honey, not at all! I didn'..., Sentiment: 0.50
# Starting real-time sentiment analysis simulation...
# Tweet 1: @ozazure I'm with you... love having visitors, esp..., Sentiment: 0.25
# Starting real-time sentiment analysis simulation...
# Tweet 1: had the worst 1st day ever!!! ..., Sentiment: -1.00
# Starting real-time sentiment analysis simulation...
# Tweet 1: Working late on Friday  tons of stuff to do for ne..., Sentiment: -0.15
# Starting real-time sentiment analysis simulation...
# Tweet 1: still revising  Lufbra experience awards tonight !..., Sentiment: 0.50
# Starting real-time sentiment analysis simulation...
# Tweet 1: @Burkazoid  ill keep me fingers crossed for you! o..., Sentiment: -0.54
# Starting real-time sentiment analysis simulation...
# Tweet 1: @buddhawong you just found ooooout ?  imy by the w..., Sentiment: 0.00
# Starting real-time sentiment analysis simulation...
# Tweet 1: @didilaksana I almost went over its garden because..., Sentiment: 0.00
# Starting real-time sentiment analysis simulation...
# Tweet 1: @shelbikins Yep they are alll good ..., Sentiment: 0.70
# Starting real-time sentiment analysis simulation...
# Tweet 1: this nba season has been crazzzzyy..and like anyon..., Sentiment: -0.62
# Starting real-time sentiment analysis simulation...
# Tweet 1: OH EM F'ING GEEEE I NEVER KNEWWW! NEVER WOULD HAVE..., Sentiment: 0.10
# Starting real-time sentiment analysis simulation...
# Tweet 1: @compelledtoread ..., Sentiment: 0.00
# Starting real-time sentiment analysis simulation...
# Tweet 1: Just got back from grocery shopping at 11PM.  Not ..., Sentiment: 0.02
# Starting real-time sentiment analysis simulation...
# Tweet 1: I thought it was Monday... until my sister said it..., Sentiment: 0.00
# Starting real-time sentiment analysis simulation...
# Tweet 1: I just got a headache ..., Sentiment: 0.00
# Starting real-time sentiment analysis simulation...
# Tweet 1: @VenusEnvy Yeah, you TOTALLY don't look like sopme..., Sentiment: 0.00
# Starting real-time sentiment analysis simulation...
# Tweet 1: didn't know getting back on a schedule would suck ..., Sentiment: 0.10
# Starting real-time sentiment analysis simulation...
# Tweet 1: getting ready to take a nap 3rd shift messes me up..., Sentiment: 0.10
# Starting real-time sentiment analysis simulation...
# Tweet 1: i just learned how to do the Hoedown Throwdown!  n..., Sentiment: -0.62
# Starting real-time sentiment analysis simulation...
# Tweet 1: @JessicaGottlieb Good decision. I know it's very s..., Sentiment: 0.02
# Starting real-time sentiment analysis simulation...
# Tweet 1: @gigi_sg Yup!  The former Chef Chan at Odeon Tower..., Sentiment: 0.14
# Starting real-time sentiment analysis simulation...
# Tweet 1: @herotozero my dance choreographer performed on AS..., Sentiment: -0.50
# Starting real-time sentiment analysis simulation...
# Tweet 1: @slickt614 i will dm you ..., Sentiment: 0.00
# Starting real-time sentiment analysis simulation...
# Tweet 1: oh dear. this hurts!  http://tr.im/oWLV..., Sentiment: 0.00
# Starting real-time sentiment analysis simulation...
# Tweet 1: and how wrong was i105107 about Iceland ..., Sentiment: -0.50
# Starting real-time sentiment analysis simulation...
# Tweet 1: Drinking fresh Kona coffee and watching badly acte..., Sentiment: 0.13
# Starting real-time sentiment analysis simulation...
# Tweet 1: going to fail ..., Sentiment: -0.50
# Starting real-time sentiment analysis simulation...
# Tweet 1: @LeighMolnar: I think BB is on for most of the sum..., Sentiment: 0.50
# Starting real-time sentiment analysis simulation...
# Tweet 1: @JamesMW78 its so sad when they get like that ..., Sentiment: -0.50
# Starting real-time sentiment analysis simulation...
# Tweet 1: won tickets to see the jonas brothers (: ...but of..., Sentiment: 0.00
# Starting real-time sentiment analysis simulation...
# Tweet 1: Driving through salinas.. Almost there. 67 degrees..., Sentiment: 0.00
# Starting real-time sentiment analysis simulation...
# Tweet 1: @radtke327 nice. i worked for him for a few years ..., Sentiment: 0.33

# %%
# Import required libraries
import pandas as pd
import numpy as np
from textblob import TextBlob
import yfinance as yf
import time
from datetime import datetime
import dash
from dash import dcc, html
from dash.dependencies import Input, Output
import warnings
import nltk
from nltk.sentiment import SentimentIntensityAnalyzer

warnings.filterwarnings('ignore')
nltk.download('vader_lexicon')  # Ensure VADER is available
sia = SentimentIntensityAnalyzer()

# Load sentiment dataset (using your provided file path)
dataset_path = r"C:\Users\hp\Downloads\archive (9)\training.1600000.processed.noemoticon.csv"

try:
    data = pd.read_csv(dataset_path, encoding='latin-1', header=None, 
                       names=['target', 'id', 'date', 'flag', 'user', 'text'])
    print("Dataset loaded successfully!")
except FileNotFoundError:
    print(f"File not found: {dataset_path}. Please verify the path.")
    # Assign a fallback dataset
    data = pd.DataFrame({'text': ["No dataset found. Replace with real data!"]})

# Load NIFTY data
nifty = yf.download('^NSEI', start='2024-01-01', end='2025-05-23', interval='1d')

# Improved sentiment analysis using VADER
def get_sentiment(text):
    return sia.polarity_scores(text)['compound']

# Simulated RBI policy announcements
rbi_statements = [
    "RBI maintains repo rate at 6.5% to support growth.",
    "Inflation concerns prompt RBI to tighten monetary policy.",
    "RBI introduces measures to stabilize financial markets."
]

# Process sentiment for RBI statements
rbi_sentiments = [get_sentiment(text) for text in rbi_statements]
rbi_df = pd.DataFrame({
    'Statement': rbi_statements,
    'Sentiment': rbi_sentiments,
    'Date': [datetime.now() for _ in rbi_statements]
})

# Simulate real-time tweet stream
def simulate_realtime_tweets(n_tweets=5):
    print("Starting real-time sentiment analysis simulation...")
    sentiments = []
    timestamps = []
    
    for i in range(n_tweets):
        if data.empty:
            print("No sentiment data available.")
            break
        
        tweet = data['text'].sample(1).iloc[0]  # Random tweet from dataset
        sentiment = get_sentiment(tweet)
        sentiments.append(sentiment)
        timestamps.append(datetime.now().strftime('%Y-%m-%d %H:%M:%S'))
        print(f"Tweet {i+1}: {tweet[:50]}..., Sentiment: {sentiment:.2f}")
    
    return pd.DataFrame({'Timestamp': timestamps, 'Sentiment': sentiments})

# Run simulation
tweet_data = simulate_realtime_tweets(n_tweets=5)

# Limit stored tweets to optimize memory usage
tweet_data = tweet_data.tail(100)  # Keep only the latest 100 tweets

# Create Dash app for real-time dashboard
app = dash.Dash(__name__)

app.layout = html.Div([
    html.H1("Real-Time RBI Policy Sentiment Dashboard"),
    dcc.Graph(id='sentiment-graph'),
    dcc.Interval(id='interval-component', interval=5*1000, n_intervals=0)  # Update every 5 seconds
])

@app.callback(
    Output('sentiment-graph', 'figure'),
    [Input('interval-component', 'n_intervals')]
)
def update_graph(n):
    global tweet_data
    new_data = simulate_realtime_tweets(n_tweets=1)
    tweet_data = pd.concat([tweet_data, new_data], ignore_index=True).tail(100)  # Limit to 100 tweets
    
    # Plot sentiment over time
    fig = {
        'data': [
            {'x': tweet_data['Timestamp'], 'y': tweet_data['Sentiment'], 'type': 'line', 'name': 'Tweet Sentiment'},
            {'x': rbi_df['Date'], 'y': rbi_df['Sentiment'], 'type': 'scatter', 'mode': 'markers', 'name': 'RBI Statement Sentiment'}
        ],
        'layout': {
            'title': 'Real-Time Sentiment Analysis of RBI Policy and Tweets',
            'xaxis': {'title': 'Time'},
            'yaxis': {'title': 'Sentiment Score (-1 to 1)'}
        }
    }
    return fig

# Run the app
if __name__ == '__main__':
    print("Starting Dash server... Open http://127.0.0.1:8050/ in your browser.")
    app.run(debug=True)  # Updated: Use app.run() instead of app.run_server()
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\hp\AppData\Roaming\nltk_data...
# [*********************100%***********************]  1 of 1 completed
# Dataset loaded successfully!
# Starting real-time sentiment analysis simulation...
# Tweet 1: @ronnyvengeance Hope soo ..., Sentiment: 0.44
# Tweet 2: Writing and researching. Tired of being foolish, s..., Sentiment: -0.71
# Tweet 3: @potsofgold4u Get 100 followers a day using www.tw..., Sentiment: 0.44
# Tweet 4: Omg...my fish is dying. Its so sad ..., Sentiment: -0.61
# Tweet 5: I honestly don't want to do a birthday party no mo..., Sentiment: -0.60
# Starting Dash server... Open http://127.0.0.1:8050/ in your browser.
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
# Starting real-time sentiment analysis simulation...
# Tweet 1: @klaris nilagyan mo ng knorr seasoning mix ulit un..., Sentiment: 0.61
# Starting real-time sentiment analysis simulation...
# Tweet 1: @bondsbustyblond it was fab  dickie was smiling aw..., Sentiment: 0.72
# Starting real-time sentiment analysis simulation...
# Starting real-time sentiment analysis simulation...
# Tweet 1: hrmm pretty bored ayee, liking atl atm (: tehehehe..., Sentiment: 0.79
# Tweet 1: SSSSSSSSSsssssssssssssiigh!! im never gonna get 2 ..., Sentiment: -0.34
# Starting real-time sentiment analysis simulation...
# Tweet 1: @jlamshed  ur so Bob ..., Sentiment: 0.00
# Starting real-time sentiment analysis simulation...
# Tweet 1: @MissMonaG im going!! and i know a bunch of girls ..., Sentiment: 0.00
# Starting real-time sentiment analysis simulation...
# Tweet 1: waiting for @barbs27 it wake the eff up so i can c..., Sentiment: 0.00
# Starting real-time sentiment analysis simulation...
# Tweet 1: Ugh @TreyDerbes now I have that song in my head! @..., Sentiment: -0.10
# Starting real-time sentiment analysis simulation...
# Tweet 1: @MrsSOsbourne you go Sharon! ..., Sentiment: 0.00
# Starting real-time sentiment analysis simulation...
# Tweet 1: @darylsws and @Calgemy , yep definite  improvement..., Sentiment: 0.51
# Starting real-time sentiment analysis simulation...
# Tweet 1: dont want to go shoe shpping tommorow! but its a m..., Sentiment: -0.10
# Starting real-time sentiment analysis simulation...
# Tweet 1: In geography ..., Sentiment: 0.00
# Starting real-time sentiment analysis simulation...
# Tweet 1: Watch out for the next fastest broadband tvc nyaha..., Sentiment: 0.00
# Starting real-time sentiment analysis simulation...
# Tweet 1: @Chad_DC  why cant u get one.. sell your  fugly pu..., Sentiment: 0.64
# Starting real-time sentiment analysis simulation...
# Tweet 1: waiting for our departure flight to philly. don't ..., Sentiment: 0.00
# Starting real-time sentiment analysis simulation...
# Tweet 1: Oh great it's not even halfway through the morning..., Sentiment: 0.62
# Starting real-time sentiment analysis simulation...
# Tweet 1: spending time with jane's parents... lots of food ..., Sentiment: 0.00
# Starting real-time sentiment analysis simulation...
# Tweet 1: @MariaGalea yeah me 2 cant wait for it OMJ !peace,..., Sentiment: 0.36
# Starting real-time sentiment analysis simulation...
# Tweet 1: I am @ work . Waiting on someone to come in my sto..., Sentiment: -0.22
# Starting real-time sentiment analysis simulation...
# Tweet 1: won't stop till i get a reply, sorry ..., Sentiment: 0.15
# Starting real-time sentiment analysis simulation...
# Tweet 1: http://twitpic.com/67kaa - My best friend &amp; I ..., Sentiment: 0.91
# Starting real-time sentiment analysis simulation...
# Tweet 1: says Falling in love consists merely in uncorking ..., Sentiment: 0.56
# Starting real-time sentiment analysis simulation...
# Tweet 1: @ciaranj oh noes  do u have remote access to ur pc..., Sentiment: 0.00
# Starting real-time sentiment analysis simulation...
# Tweet 1: on my way to Mel's then...the beach ..., Sentiment: 0.00
# Starting real-time sentiment analysis simulation...
# Tweet 1: Watching CSI:Miami since I'm poor to enjoy life ri..., Sentiment: 0.03
# Starting real-time sentiment analysis simulation...
# Tweet 1: says i cant open my plurk  http://plurk.com/p/ri0t..., Sentiment: 0.00
# Starting real-time sentiment analysis simulation...
# Tweet 1: FAIL! @themoshow: firefox hat alle addons gelÃ¶sch..., Sentiment: -0.67
# Starting real-time sentiment analysis simulation...
# Tweet 1: @sandyzahler Oh dear!  What is happening with the ..., Sentiment: -0.57
# Starting real-time sentiment analysis simulation...
# Tweet 1: things are kinda crappy  but i got a cd i've been ..., Sentiment: 0.34
# Starting real-time sentiment analysis simulation...
# Tweet 1: had a nightmare and is scared to sleep ever again ..., Sentiment: -0.44
# Starting real-time sentiment analysis simulation...
# Tweet 1: @nataccil hey thanks yaaa ..., Sentiment: 0.44
# Starting real-time sentiment analysis simulation...
# Tweet 1: @JLSOfficial its so broing without jlsofficial  xx..., Sentiment: -0.52
# Starting real-time sentiment analysis simulation...
# Tweet 1: wants to go to sleep S0 bad...but this homework is..., Sentiment: 0.00
# Starting real-time sentiment analysis simulation...
# Tweet 1: thanx @gigantobooks , great works 2 ..., Sentiment: 0.62
# Starting real-time sentiment analysis simulation...
# Tweet 1: a little lonely ..., Sentiment: -0.30
# Starting real-time sentiment analysis simulation...
# Tweet 1: gunna go out soon but i wish i was going horseridi..., Sentiment: 0.04
# Starting real-time sentiment analysis simulation...
# Tweet 1: lalalala. pretty stressed. trying to write a bio e..., Sentiment: 0.20
# Starting real-time sentiment analysis simulation...
# Tweet 1: @MandyyJirouxx OMG what no tomato soup that sucks ..., Sentiment: -0.20
# Starting real-time sentiment analysis simulation...
# Tweet 1: I'm sad to see The Real Housewives of New Jersey e..., Sentiment: -0.12
# Starting real-time sentiment analysis simulation...
# Tweet 1: @campbeltonian Big up the Tunnocks ..., Sentiment: 0.00
# Starting real-time sentiment analysis simulation...
# Tweet 1: @Ranieka Likin the myspace page ..., Sentiment: 0.00
# Starting real-time sentiment analysis simulation...
# Tweet 1: Almost to work. I didn't wanna leave bed this morn..., Sentiment: 0.04
# Starting real-time sentiment analysis simulation...
# Tweet 1: @Hannanar its my birthday tomorrowwwww ..., Sentiment: 0.00
# Starting real-time sentiment analysis simulation...
# Tweet 1: I have a gigantic headache. ..., Sentiment: 0.00
# Starting real-time sentiment analysis simulation...
# Tweet 1: @vautrin Job interviews? What happened to the one ..., Sentiment: 0.00
# Starting real-time sentiment analysis simulation...
# Tweet 1: Good morning ..., Sentiment: 0.44
# Starting real-time sentiment analysis simulation...
# Tweet 1: can play this game all day long, but you've guesse..., Sentiment: -0.43
# Starting real-time sentiment analysis simulation...
# Tweet 1: so tired ..., Sentiment: -0.49
# Starting real-time sentiment analysis simulation...
# Tweet 1: is so fucking tired. I just wanna go to bed ..., Sentiment: -0.54
# Starting real-time sentiment analysis simulation...
# Tweet 1: back from the lake! good news and bad news: the ho..., Sentiment: 0.42
# Starting real-time sentiment analysis simulation...
# Tweet 1: @poker_sports Get 100 followers a day using www.tw..., Sentiment: 0.44
# Starting real-time sentiment analysis simulation...
# Tweet 1: @kristinak__ i knooooooooooooow!! ive been super b..., Sentiment: 0.67
# Starting real-time sentiment analysis simulation...
# Tweet 1: I'm sleepy, I go to bed! GoodKnight friends!! Nice..., Sentiment: 0.91
# Starting real-time sentiment analysis simulation...
# Tweet 1: is gonna have some fun tonight ..., Sentiment: 0.51
# Starting real-time sentiment analysis simulation...
# Tweet 1: @wicksie the 'sinister minister' would never do th..., Sentiment: -0.60
# Starting real-time sentiment analysis simulation...
# Tweet 1: r.i.p air france pax ..., Sentiment: 0.00
# Starting real-time sentiment analysis simulation...
# Tweet 1: Chilling in the pool with Kassi for a few hours wh..., Sentiment: -0.03
# Starting real-time sentiment analysis simulation...
# Tweet 1: @FAITHL0VEH0PE I guess if you can't accept me....i..., Sentiment: -0.29
# Starting real-time sentiment analysis simulation...
# Tweet 1: Is wishing some thing's &amp; people didn't ever c..., Sentiment: 0.23
# Starting real-time sentiment analysis simulation...
# Tweet 1: @BiGVixXen :S I asked to play with u in COD but u ..., Sentiment: -0.07
# Starting real-time sentiment analysis simulation...
# Tweet 1: @echoparkgal  u can also use 1tsp of salt to 1/4fi..., Sentiment: 0.78
# Starting real-time sentiment analysis simulation...
# Tweet 1: @backstreetboys hey B-Rye...lol. j/k LOVED UR ANSW..., Sentiment: 0.84
# Starting real-time sentiment analysis simulation...
# Tweet 1: @hmason Hope you get better soon. Stay away from t..., Sentiment: 0.70
# Starting real-time sentiment analysis simulation...
# Tweet 1: finished piano w/ sam. eating yogurt ice-cream and..., Sentiment: 0.00
# Starting real-time sentiment analysis simulation...
# Tweet 1: its too late and tomorrow I have a very hectic day..., Sentiment: 0.00
# Starting real-time sentiment analysis simulation...
# Tweet 1: @evandenbranden No pressure then ..., Sentiment: -0.53
# Starting real-time sentiment analysis simulation...
# Tweet 1: @redphx Mong t?i thï¿½ng 6 ?? ?? tu?i l?y v? ï¿½! ..., Sentiment: 0.00
# Starting real-time sentiment analysis simulation...
# Tweet 1: My county allows you to pay your tickets online......, Sentiment: -0.44
# Starting real-time sentiment analysis simulation...
# Tweet 1: @sexinstilettos its cute. and i like the name ..., Sentiment: 0.67
# Starting real-time sentiment analysis simulation...
# Tweet 1: At the mall again wit my girl. Tryin 2 find a dres..., Sentiment: 0.00
# Starting real-time sentiment analysis simulation...
# Tweet 1: @sixapart why can't I get the TypePad app for my B..., Sentiment: 0.00
# Starting real-time sentiment analysis simulation...
# Tweet 1: Hangover ouchies ..., Sentiment: 0.00
# Starting real-time sentiment analysis simulation...
# Tweet 1: I'm dying a slow slow death right now  Hangover + ..., Sentiment: -0.83
# Starting real-time sentiment analysis simulation...
# Tweet 1: @VIP_STATUS  nobody n the industry likes natural l..., Sentiment: 0.80
# Starting real-time sentiment analysis simulation...
# Tweet 1: @drdariush has been here since 10:08 AM Mar 18th, ..., Sentiment: 0.27
# Starting real-time sentiment analysis simulation...
# Tweet 1: I made a wish ..., Sentiment: 0.40
# Starting real-time sentiment analysis simulation...
# Tweet 1: @sosodeformed TMobile is great w unlocked devices,..., Sentiment: 0.61
# Starting real-time sentiment analysis simulation...
# Tweet 1: @bucky4eyes LOL, I'll tell him you said so.  He'll..., Sentiment: 0.87
# Starting real-time sentiment analysis simulation...
# Tweet 1: @iarerawbot im also lapar, tapi no food. cam sial ..., Sentiment: -0.30
# Starting real-time sentiment analysis simulation...
# Tweet 1: @Eiwen rest up buddy... watch a good movie and rel..., Sentiment: 0.70
# Starting real-time sentiment analysis simulation...
# Tweet 1: @velashleyraptor its ur couch charge them by the h..., Sentiment: 0.00
# Starting real-time sentiment analysis simulation...
# Tweet 1: Reached my bsnl usage limit ..., Sentiment: 0.10
# Starting real-time sentiment analysis simulation...
# Tweet 1: What are we all feeling so far? I think it's betwe..., Sentiment: -0.38
# Starting real-time sentiment analysis simulation...
# Tweet 1: @empireofno they said on the bbc that clinic has h..., Sentiment: 0.00
# Starting real-time sentiment analysis simulation...
# Tweet 1: i want to go on holiday to somewhere very hot ..., Sentiment: 0.46

# %%
# Import required libraries
import pandas as pd
import numpy as np
from textblob import TextBlob
import yfinance as yf
import time
from datetime import datetime
import dash
from dash import dcc, html
from dash.dependencies import Input, Output
import warnings
import nltk
from nltk.sentiment import SentimentIntensityAnalyzer
import os  # Added to verify dataset existence

warnings.filterwarnings('ignore')
nltk.download('vader_lexicon')  # Ensure VADER is available
sia = SentimentIntensityAnalyzer()

# Load sentiment dataset (using your provided file path)
dataset_path = r"C:\Users\hp\Downloads\archive (9)\training.1600000.processed.noemoticon.csv"

if os.path.exists(dataset_path):
    try:
        data = pd.read_csv(dataset_path, encoding='latin-1', header=None, 
                           names=['target', 'id', 'date', 'flag', 'user', 'text'])
        print("✅ Dataset loaded successfully!")
    except Exception as e:
        print(f"❌ Error loading dataset: {e}")
        data = pd.DataFrame(columns=['text'])  # Empty DataFrame as fallback
else:
    print(f"❌ File not found: {dataset_path}. Please verify the path.")
    data = pd.DataFrame(columns=['text'])  # Empty DataFrame as fallback

# Load NIFTY data
nifty = yf.download('^NSEI', start='2024-01-01', end='2025-05-23', interval='1d')

# Improved sentiment analysis using VADER
def get_sentiment(text):
    return sia.polarity_scores(text)['compound']

# Simulated RBI policy announcements
rbi_statements = [
    "RBI maintains repo rate at 6.5% to support growth.",
    "Inflation concerns prompt RBI to tighten monetary policy.",
    "RBI introduces measures to stabilize financial markets."
]

# Process sentiment for RBI statements
rbi_sentiments = [get_sentiment(text) for text in rbi_statements]
rbi_df = pd.DataFrame({
    'Statement': rbi_statements,
    'Sentiment': rbi_sentiments,
    'Date': [datetime.now() for _ in rbi_statements]
})

# Simulate real-time tweet stream
def simulate_realtime_tweets(n_tweets=5):
    print("🔹 Starting real-time sentiment analysis simulation...")
    sentiments = []
    timestamps = []

    if data.empty:
        print("⚠ No sentiment data available. Ensure dataset is loaded.")
        return pd.DataFrame({'Timestamp': [], 'Sentiment': []})  # Return empty DataFrame

    for i in range(n_tweets):
        tweet = data['text'].sample(1).iloc[0]  # Random tweet from dataset
        sentiment = get_sentiment(tweet)
        sentiments.append(sentiment)
        timestamps.append(datetime.now().strftime('%Y-%m-%d %H:%M:%S'))
        print(f"📢 Tweet {i+1}: {tweet[:50]}..., Sentiment: {sentiment:.2f}")

    return pd.DataFrame({'Timestamp': timestamps, 'Sentiment': sentiments})

# Run simulation
tweet_data = simulate_realtime_tweets(n_tweets=5)

# Limit stored tweets to optimize memory usage
tweet_data = tweet_data.tail(100)  # Keep only the latest 100 tweets

# Create Dash app for real-time dashboard
app = dash.Dash(__name__)

app.layout = html.Div([
    html.H1("Real-Time RBI Policy Sentiment Dashboard"),
    dcc.Graph(id='sentiment-graph'),
    dcc.Interval(id='interval-component', interval=5*1000, n_intervals=0)  # Update every 5 seconds
])

@app.callback(
    Output('sentiment-graph', 'figure'),
    [Input('interval-component', 'n_intervals')]
)
def update_graph(n):
    global tweet_data
    new_data = simulate_realtime_tweets(n_tweets=1)
    tweet_data = pd.concat([tweet_data, new_data], ignore_index=True).tail(100)  # Limit to latest 100 tweets

    # Plot sentiment over time
    fig = {
        'data': [
            {'x': tweet_data['Timestamp'], 'y': tweet_data['Sentiment'], 'type': 'line', 'name': 'Tweet Sentiment'},
            {'x': rbi_df['Date'], 'y': rbi_df['Sentiment'], 'type': 'scatter', 'mode': 'markers', 'name': 'RBI Statement Sentiment'}
        ],
        'layout': {
            'title': '📊 Real-Time Sentiment Analysis of RBI Policy and Tweets',
            'xaxis': {'title': 'Time'},
            'yaxis': {'title': 'Sentiment Score (-1 to 1)'}
        }
    }
    return fig

# Run the app
if __name__ == '__main__':
    print("🌐 Starting Dash server... Open http://127.0.0.1:8050/ in your browser.")
    app.run(debug=True)  # Updated: Use app.run() instead of app.run_server()
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\hp\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [*********************100%***********************]  1 of 1 completed
# ✅ Dataset loaded successfully!
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: seriously me being sick has to stop NOW i really r..., Sentiment: -0.35
# 📢 Tweet 2: @SenorDanimal &quot;not now Pinky, I'm *fuming*&qu..., Sentiment: 0.00
# 📢 Tweet 3: @thekenyeung homeboy, In-n-Out comes after Hooters..., Sentiment: 0.00
# 📢 Tweet 4: So glad I'm finally done with finals! ..., Sentiment: 0.56
# 📢 Tweet 5: @MolsonFL No such luck here &amp; the TV isn't any..., Sentiment: 0.60
# 🌐 Starting Dash server... Open http://127.0.0.1:8050/ in your browser.
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: @geekgirl444 - '10-4', it's good to have clear 'gr..., Sentiment: 0.67
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: I can't believe that Racing Victoria has lifted th..., Sentiment: -0.86
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: @mrnbcox Both! hehehe... Saw your parents last nig..., Sentiment: -0.39
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: @johnmisczak I get incredibly depressed when I got..., Sentiment: -0.56
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: @EdwardIkhwan It's up on Ning! Go check it out. It..., Sentiment: 0.00
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: I kno a big huge meanie  ..., Sentiment: 0.32
# 🔹 Starting real-time sentiment analysis simulation...🔹 Starting real-time sentiment analysis simulation...
#
# 📢 Tweet 1: i cant believe that this was my last performance a..., Sentiment: -0.74
# 📢 Tweet 1: @johncmayer Hey-- instead of flowers--my husband b..., Sentiment: 0.75
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: http://twitpic.com/6cd09 - my biology class, the l..., Sentiment: 0.00
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: http://twitpic.com/66yag - Follow Me To The Moon ..., Sentiment: 0.00
# 🔹 Starting real-time sentiment analysis simulation...🔹 Starting real-time sentiment analysis simulation...
#
# 📢 Tweet 1: I want me some Southerngold ..., Sentiment: 0.08📢 Tweet 1: @JulianneBelle i hate your homework!  but you will..., Sentiment: -0.50
#
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: @Dojie ok re orders the flowers ..., Sentiment: 0.30
# 🔹 Starting real-time sentiment analysis simulation...🔹 Starting real-time sentiment analysis simulation...
#
# 📢 Tweet 1: I find I'm using the stroke nib as my main one on ..., Sentiment: 0.44
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: I hate thunder  It's frightening..., Sentiment: -0.78
# 📢 Tweet 1: @mollymahlou I'm really hating religion  Amelia an..., Sentiment: -0.56
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: The icon-makers at BSG Stillness will be working w..., Sentiment: 0.00
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: @williams1 the maldives are a very hard place to l..., Sentiment: -0.22
# 🔹 Starting real-time sentiment analysis simulation...
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: bought a fake Blur record. i don't deserve to live..., Sentiment: -0.48
# 📢 Tweet 1: Forum: Your Favourite Album Covers:   I know how t..., Sentiment: 0.00
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: @ninjen, mornin'! Some kind of #followsaturday? ..., Sentiment: 0.00
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: @ByYourSide2009 I good. Didn't understand ur last ..., Sentiment: 0.44
# 🔹 Starting real-time sentiment analysis simulation...
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: @KimmyLauren the full moon is tomorrow  enjoy your..., Sentiment: 0.49
# 📢 Tweet 1: 1 Day Till sanantoniohackers.org, 2 day's till Bur..., Sentiment: 0.00
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1:  @LadyKeisha @scorpio510 thanx for the post &amp; ..., Sentiment: 0.66
# 🔹 Starting real-time sentiment analysis simulation...
# 🔹 Starting real-time sentiment analysis simulation...
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: @drumstickboy Ohgod,  I feel sad for you. Anyway, ..., Sentiment: -0.48
# 📢 Tweet 1: the NBA draft is finally here..today it will cut i..., Sentiment: 0.62
# 📢 Tweet 1: good morgning, world. im still tired from yesterda..., Sentiment: 0.76
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: @aordinarylife Good Luck tomorrow!!  Wishing you &..., Sentiment: 0.87
# 🔹 Starting real-time sentiment analysis simulation...
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: http://bit.ly/bHyt8  Salieri and the Priest ..., Sentiment: 0.00
# 📢 Tweet 1: just baked a cake and it looks horrible ..., Sentiment: -0.54
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: @icedcoffee Flickr Pro has more sets and collectio..., Sentiment: 0.08
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: Oh, and did I mention that this might be the last ..., Sentiment: -0.27
# 🔹 Starting real-time sentiment analysis simulation...
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: @ChrystinaGrace Chrystina Grace Timberlake has a r..., Sentiment: 0.48
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: @honeysugarwater see.. using twitter for good it's..., Sentiment: 0.70
# 📢 Tweet 1: Well up for a bit of superbadness but will just fa..., Sentiment: 0.14
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: @sioksiok well u know, gotta have my priorities st..., Sentiment: 0.46
# 🔹 Starting real-time sentiment analysis simulation...
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: @candiceshelley great taste in music ..., Sentiment: 0.62
# 📢 Tweet 1: @trepdiation90 i will follow you to the ends of th..., Sentiment: 0.64
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: Sitting here feeling slightly lonely ...    But ta..., Sentiment: -0.24
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: will be teaching Greography Today ..., Sentiment: 0.00
# 🔹 Starting real-time sentiment analysis simulation...
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: he will take a break n i will miss him so much  ))..., Sentiment: -0.15
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: Awww. @kelton_2328's lovely corsage 4 his prom dat..., Sentiment: 0.59
# 📢 Tweet 1: @E_Brock  thanx. I'm sumwhere on 75 now lol..., Sentiment: 0.42
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: sitting in the wegmans cafe waiting for joel to fi..., Sentiment: 0.61
# 🔹 Starting real-time sentiment analysis simulation...
# 🔹 Starting real-time sentiment analysis simulation...
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: is staying home from church because of allergies a..., Sentiment: 0.00
# 📢 Tweet 1: feels like I'm on punishment ..., Sentiment: -0.18
# 📢 Tweet 1: BOOOOOOOOOO.  3.0 software delayed til tomorrow!  ..., Sentiment: -0.29
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: @ketnos pepper is dead   the cpu fan wire got cut ..., Sentiment: -0.84
# 🔹 Starting real-time sentiment analysis simulation...
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: I wonder what it feels like to have a mustache. Or..., Sentiment: 0.36🔹 Starting real-time sentiment analysis simulation...
#
# 📢 Tweet 1: @ThePDXGuy  ..., Sentiment: 0.00
# 📢 Tweet 1: @WENBlog listening to it now ..., Sentiment: 0.00
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: Wow, Twitter finally let me upload a picture! ..., Sentiment: 0.62
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: LIKE I SAID, CHUCKK OFFFF   and with that, im goin..., Sentiment: 0.50
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: If you feel offensed by dumbass marketing on Twitt..., Sentiment: -0.80
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: @JennAWhitson said I should tweet our last convo....., Sentiment: 0.00
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: PISSED!! And i wish @bballcourt04 was around for m..., Sentiment: -0.59
# 🔹 Starting real-time sentiment analysis simulation...
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: this heat rash i'm sporting is very fetching - lun..., Sentiment: -0.20
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: @DebbieFletcher yeah, tommcfly is good! i like  de..., Sentiment: 0.47
# 📢 Tweet 1: watered the lawn about and hour ago, it is now rai..., Sentiment: 0.00
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: Back to work.  wish i could take a week off and go..., Sentiment: 0.46
# 🔹 Starting real-time sentiment analysis simulation...
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: @dauphong Äi cÃ´ng viá»c Äáº¥y chá»©  mua ÄÄ©a..., Sentiment: 0.00
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: Laying on bed surrounded by revision books ..., Sentiment: 0.00
# 📢 Tweet 1: @LeaWhiteFeather that sounds really yummy! I miss ..., Sentiment: 0.48
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: @whoisralphie dude  I'm so bummed ur leaving!..., Sentiment: 0.00
# 🔹 Starting real-time sentiment analysis simulation...
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: @lynnali2 come do mine please ..., Sentiment: 0.32
# 📢 Tweet 1: is waiting for this week to fly by.. then Bangalor..., Sentiment: 0.00
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: @Chopsticka42 you can never have too much wow  but..., Sentiment: 0.71
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: EY asked me for a ride to the airport. This is her..., Sentiment: 0.00
# 🔹 Starting real-time sentiment analysis simulation...
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: I agree...stupid tiredness ..., Sentiment: 0.00
# 📢 Tweet 1: its gonna start to rain no more skating for me ..., Sentiment: -0.30
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: @markreadmusic Just watching A1 vids! Forgot how a..., Sentiment: 0.94
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: One of our two black cats (Void) is sneezing blood..., Sentiment: -0.66
# 🔹 Starting real-time sentiment analysis simulation...
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: texting ..., Sentiment: 0.00
# 📢 Tweet 1: video-conferencing really does add 10lbs ..., Sentiment: 0.00
# 🔹 Starting real-time sentiment analysis simulation...
# 🔹 Starting real-time sentiment analysis simulation...📢 Tweet 1: at work till 2:30 tonight ..., Sentiment: 0.00
#
# 📢 Tweet 1: @Nellypt  tweet ya tomorrow...., Sentiment: 0.00
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: @PriscillaF *hugs* ..., Sentiment: 0.00🔹 Starting real-time sentiment analysis simulation...
#
# 📢 Tweet 1: @katiekuddles lol. Yeah! He's my favorite person e..., Sentiment: 0.81
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: No Boys Till 9th Grade  I'm just a kid...I wanna l..., Sentiment: -0.53
# 🔹 Starting real-time sentiment analysis simulation...
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: @sggaffney ..., Sentiment: 0.00
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: Yesss but when someone gives me a ride! ..., Sentiment: 0.00📢 Tweet 1: I've got an upset stomach  Damn cookies, ice cream..., Sentiment: -0.73
#
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: When will Trey and Stella learn to sleep in?  This..., Sentiment: -0.22
# 🔹 Starting real-time sentiment analysis simulation...🔹 Starting real-time sentiment analysis simulation...
#
# 📢 Tweet 1: http://twitpic.com/5oqcb - 5M Camera in water-proo..., Sentiment: 0.44
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: remembered my login details lol!! not been up to m..., Sentiment: 0.57
# 📢 Tweet 1: Scrapbooking made easy!!!    At the Charos househo..., Sentiment: 0.91
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: goin back home  ... standin on hyderabad intnl air..., Sentiment: 0.00
# 🔹 Starting real-time sentiment analysis simulation...
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: Did some location scouting yesterday. First time o..., Sentiment: 0.69
# 📢 Tweet 1: pretty much bummed out that terminator salvation w..., Sentiment: 0.20
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: lol @HauteFuss cant now I aint home. when i am hom..., Sentiment: 0.15
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: boat got rained out.    ..., Sentiment: 0.00
# 🔹 Starting real-time sentiment analysis simulation...
# 🔹 Starting real-time sentiment analysis simulation...
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: sitting in hospital with jaimie and her new baby ..., Sentiment: 0.00
# 📢 Tweet 1: @xpezcorex I am very glad, too! And I never doubte..., Sentiment: 0.66📢 Tweet 1: Its days like these when I hate being ginger. I ha..., Sentiment: -0.36
#
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: y do i even bother getting a new fone..i just fuck..., Sentiment: -0.34
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: @Patrykxoxo aww your so sweet finding your sissy a..., Sentiment: 0.59
# 🔹 Starting real-time sentiment analysis simulation...
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: @ThinkingSheep I am lost. Please help me find a go..., Sentiment: 0.68
# 📢 Tweet 1: Starting to get a little bored.  ..., Sentiment: -0.20
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: @gulpanag i missed ..., Sentiment: -0.30
# 🔹 Starting real-time sentiment analysis simulation...
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: @mitchelmusso hey mitch ur CD is awesome. worth wa..., Sentiment: 0.72
# 🔹 Starting real-time sentiment analysis simulation...📢 Tweet 1: is not in a good mood ! ..., Sentiment: -0.40
#
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: Iz headed to band practice. ..., Sentiment: 0.00
# 📢 Tweet 1: noooooo braai is cancelled hmmm i have to cook now..., Sentiment: -0.25
# 🔹 Starting real-time sentiment analysis simulation...
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: Answer to my last Tweet is coffee ..., Sentiment: 0.00
# 🔹 Starting real-time sentiment analysis simulation...📢 Tweet 1: @Dan88w guess the episode ..., Sentiment: 0.00
#
# 📢 Tweet 1: should play cricket today .. ... Almost after an y..., Sentiment: 0.34
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: @cakewrecks the universe sent that sign just for Y..., Sentiment: 0.00
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: @karleigh http://twitpic.com/360do - Ahhh I love t..., Sentiment: 0.89
# 🔹 Starting real-time sentiment analysis simulation...
# 🔹 Starting real-time sentiment analysis simulation...📢 Tweet 1: night &amp; the museum in a half hour  yay!..., Sentiment: 0.57
#
# 📢 Tweet 1: I wish the weekend was longer  less than 90 days u..., Sentiment: 0.72
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: I think the writing may be on the cards already fo..., Sentiment: 0.00
# 🔹 Starting real-time sentiment analysis simulation...
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: @itsonlymecamy FC not working again ..., Sentiment: 0.00
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: Good Morning All! Live today like the triumphant b..., Sentiment: 0.97
# 📢 Tweet 1: i need a good hug right about now. and i'm missing..., Sentiment: 0.79
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: So tired long day at work...going to bed to then w..., Sentiment: -0.49
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: @elementz i had to buy mine from cold storage ..., Sentiment: 0.00
# 🔹 Starting real-time sentiment analysis simulation...
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: @johnsykes1035 Only Death is final! Only Foreclosu..., Sentiment: -0.81
# 📢 Tweet 1: @ImogenD How tragic!  What's worse is that i've be..., Sentiment: -0.75
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: Going ny night! Early day tomorrow. Back to mass. ..., Sentiment: 0.00
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: i hate NOT having internet for several weeks ..., Sentiment: -0.57🔹 Starting real-time sentiment analysis simulation...
#
# 🔹 Starting real-time sentiment analysis simulation...📢 Tweet 1: One really can't value family enough... even if th..., Sentiment: -0.57
#
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: is sending Good Luck to Marisuca!!! ..., Sentiment: 0.78📢 Tweet 1: Bravo and Andy left free beer so Bravo could poop ..., Sentiment: 0.72
#
# 🔹 Starting real-time sentiment analysis simulation...
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: Ohh no I'm craving for Kebab. Specifically shish k..., Sentiment: -0.36
# 🔹 Starting real-time sentiment analysis simulation...📢 Tweet 1: Lovely sunny day in Plymouth. So i think I will sp..., Sentiment: 0.77
#
# 📢 Tweet 1: I dreamt I arrived in LAX for E3 with no laptop or..., Sentiment: 0.45
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: I'm actually tired  nighty night..., Sentiment: -0.44
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: @b_loyal Thank you!!! you're the sweetest ..., Sentiment: 0.52
# 🔹 Starting real-time sentiment analysis simulation...
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: It's Father's Day, and my father isn't here.   But..., Sentiment: 0.79
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: New version (.26) of tweetdeck available... allows..., Sentiment: -0.22
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: @LauraSpragge  Thanks! I'll check it out. ..., Sentiment: 0.49
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: http://twitpic.com/4eya9 - Flower and her new babi..., Sentiment: 0.00
# 🔹 Starting real-time sentiment analysis simulation...📢 Tweet 1: @sammiechacha LOL ok! Sounds good. Hahaha, aww I k..., Sentiment: 0.81
#
# 📢 Tweet 1: @KhloeKardashian i admire you the most ..., Sentiment: 0.48
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: @kaypros I love those pictures! Thanks so much for..., Sentiment: 0.81
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: Piano showroom in Fulham is almost ready! I've enj..., Sentiment: 0.69
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: Just got back from my aunts house!  was fun, but n..., Sentiment: 0.46
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: @sellout No way, you're coming here and I'm going ..., Sentiment: -0.44
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: @amazcuna So many people with headaches in the off..., Sentiment: 0.00
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: @tweetybenbo but my cadigan is a guys one, bought ..., Sentiment: 0.50
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: @sammyenn perhaps it may get a bit p.l.u.r-ish at ..., Sentiment: 0.36
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: @lisaborden menu at pure food and wine sounds amaz..., Sentiment: 0.86
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: Exams looming make me feel really tense and anxiou..., Sentiment: -0.29
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: And there is the Union Oyster House... No @DonnieW..., Sentiment: -0.30
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: tired ... bored .... lonley ... max my puppy is cr..., Sentiment: -0.80
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: cant wait for june to come! babe's enrolled in ust..., Sentiment: 0.65
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: @nicktansy Why? ..., Sentiment: 0.00
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: New video is uploading! @WhoaSara24 You make me ha..., Sentiment: 0.65
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: I really wish people would stop asking about my sc..., Sentiment: 0.20
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: @tommcfly u have twitter on your screen ..., Sentiment: 0.00
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: is off to eat dinner and in an hour watch David Co..., Sentiment: 0.00🔹 Starting real-time sentiment analysis simulation...
#
# 📢 Tweet 1: went shopping and now i'm watching the first seaso..., Sentiment: 0.46
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: wishes it was cider o'clock ..., Sentiment: 0.15
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: I have so much acid in my stomach I may keel over ..., Sentiment: -0.60
# 🔹 Starting real-time sentiment analysis simulation...🔹 Starting real-time sentiment analysis simulation...
#
# 📢 Tweet 1: @ChrisCredendino Rainy.  I'm trying to talk everyo..., Sentiment: -0.04
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: Is going to play a round of mini golf w/ the entir..., Sentiment: 0.34
# 📢 Tweet 1: My 4 year old Immanuel prayed to God to get the po..., Sentiment: 0.34
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: cant sleep  cant stop coughing ..., Sentiment: -0.17
# 🔹 Starting real-time sentiment analysis simulation...
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: Went out, met Joe, am happy, hope he calls.  Won't..., Sentiment: 0.80
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: @Angry_Pangolin no more tea  makes me sad, but mus..., Sentiment: -0.39
# 📢 Tweet 1: http://twitpic.com/4ds13 - My cards are finished!!..., Sentiment: 0.00
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: @Dojie good as long as you are fine.he mustbe an a..., Sentiment: 0.10
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: @jezenia ur ass is crazy! can we not discuss the p..., Sentiment: -0.81
# 🔹 Starting real-time sentiment analysis simulation...
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: Ps- how on earth could I forget her? She's unforge..., Sentiment: -0.23
# 📢 Tweet 1: @michelledodd ..., Sentiment: 0.00
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: Happy Birthday to my puppy, Chloe.  taking her for..., Sentiment: 0.61
# 🔹 Starting real-time sentiment analysis simulation...
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: Just realized I had cheesecake the other day with ..., Sentiment: 0.00📢 Tweet 1: @nhoustonreed Happy (belated) bday from Down Under..., Sentiment: 0.67
#
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: @erin_melissa youre a fatty! ily but ..., Sentiment: 0.46
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: @Caleyjags2009 ahh sadly didn't miss you, was too ..., Sentiment: 0.40
# 🔹 Starting real-time sentiment analysis simulation...
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: @samsonator oh yeahh, still wishing that I could t..., Sentiment: 0.23🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: @corinnedekker hi again, sorry was going to pass o..., Sentiment: -0.32
#
# 📢 Tweet 1: I didn't know that a single text message can make ..., Sentiment: 0.36
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: Sore back! ..., Sentiment: -0.42
# 🔹 Starting real-time sentiment analysis simulation...
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: ciao for now. ..., Sentiment: 0.00
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: @tommcfly REALLY weird! haha and I'm doing it ..., Sentiment: 0.37
# 📢 Tweet 1: @Thea_Smith So sorry you're having a hard day. Hop..., Sentiment: 0.63
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: Bailey has a hard life!! My sick boy   http://yfro..., Sentiment: -0.65
# 🔹 Starting real-time sentiment analysis simulation...
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: where are you bee. ..., Sentiment: 0.00
# 📢 Tweet 1: Upset my dream of meetin N-Dubz isn't real  ohhh i..., Sentiment: 0.60
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: @yowneh Awww.  ..., Sentiment: 0.00
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: Good morning  everyone. Lets twitter! ..., Sentiment: 0.49
# 🔹 Starting real-time sentiment analysis simulation...
# 🔹 Starting real-time sentiment analysis simulation...
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: @DH_Photography Lucknow ..., Sentiment: 0.00
# 📢 Tweet 1: @mossyrants @CTrouper Ermm, yeah, unfortunately I'..., Sentiment: -0.52📢 Tweet 1: @thebookbark hi! I may call you Jennifer for the r..., Sentiment: 0.85
#
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: I think today is/was the best day ever! ..., Sentiment: 0.67
# 🔹 Starting real-time sentiment analysis simulation...
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: they wud do cris cos there long haul and im not  o..., Sentiment: 0.00
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: Finally home in Chico. Boohoo I have a lil sunburn..., Sentiment: 0.00
# 📢 Tweet 1: Totally not sleeping yet. Plum juice is awesome, n..., Sentiment: 0.71
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: Oh come on, have a visit  http://www.keb-s.deviant..., Sentiment: 0.00
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: Thanks to my tantrum throwing havoc creator niece,..., Sentiment: -0.81
# 🔹 Starting real-time sentiment analysis simulation...
# 🔹 Starting real-time sentiment analysis simulation...📢 Tweet 1: @boagworld Oh, man! Badger badger badger! One of m..., Sentiment: 0.00
#
# 📢 Tweet 1: Kept up at night with thoughts of my jalapeno and ..., Sentiment: -0.27
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: @austingrade I like the setup. Simple and clean. S..., Sentiment: 0.64
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: @CourtneyCummz  GOING TO BED HORNY IS NOT GOOD ..., Sentiment: -0.45
# 🔹 Starting real-time sentiment analysis simulation...
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: goodnight tweeps... practice was gr8 tonight... we..., Sentiment: 0.57
# 📢 Tweet 1: update: cousin has to have surgery either tonight ..., Sentiment: 0.51
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: now that she iis finally off it it's time for my s..., Sentiment: -0.36
# 🔹 Starting real-time sentiment analysis simulation...🔹 Starting real-time sentiment analysis simulation...
#
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: &quot;Ouch&quot;   #ChuckMeMondays #chuck..., Sentiment: 0.00
# 📢 Tweet 1: @LaurennTheLion same, just updating my MySpace, br..., Sentiment: 0.91
# 📢 Tweet 1: the party went well. Met a few people  a cousins i..., Sentiment: 0.59
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: @bronzegoddess24 hahaha if it's horrible, you shou..., Sentiment: 0.03
# 🔹 Starting real-time sentiment analysis simulation...
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: @kev_mck Alright... deal... goodnight ..., Sentiment: 0.00
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: @LadyLogan wow!!  Thanks!!  ..., Sentiment: 0.83
# 📢 Tweet 1: Little one got her first bike today! The sad news ..., Sentiment: -0.53
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: @Emizzle4 awww  Some time when you have a free wee..., Sentiment: 0.87
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: @taylorswift13 Ya do a rap song. I can tell all my..., Sentiment: 0.48
# 🔹 Starting real-time sentiment analysis simulation...
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: @kateisbored I feel the same way, but I guess no m..., Sentiment: -0.39
# 📢 Tweet 1: Need to send emails to 100,000  contacts? Check ou..., Sentiment: 0.00
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: @LindyAnn It's a pretty nice airport really - I've..., Sentiment: 0.72
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: @JuliaBronwyn I accidently dropped it &amp; now th..., Sentiment: -0.34
# 🔹 Starting real-time sentiment analysis simulation...
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: @NatiChan awww ..., Sentiment: 0.00📢 Tweet 1: am missing salsa sooooooo much....cant blve going ..., Sentiment: -0.68
#
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: is rather sick of studying..but exams start on Mon..., Sentiment: -0.51
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: @TomFelton Heeey Tom! You're awesomeee ..., Sentiment: 0.00
# 🔹 Starting real-time sentiment analysis simulation...
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: @TerribleD_UOE @UOE_Steven now now. Let's just all..., Sentiment: 0.57📢 Tweet 1: @brian_littrell Hey there! WELCUM! Finally Man! I ..., Sentiment: 0.00
# 🔹 Starting real-time sentiment analysis simulation...
#
# 📢 Tweet 1: @LisaSawyer I can't find anything to wear ..., Sentiment: 0.00
# 🔹 Starting real-time sentiment analysis simulation...
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: back to watching tv might be buying some diamonds ..., Sentiment: 0.00
# 📢 Tweet 1: Ugh monday yet again ..., Sentiment: -0.42
# 🔹 Starting real-time sentiment analysis simulation...
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: @melannievc yeah the music video is really amazing..., Sentiment: 0.74
# 📢 Tweet 1: Trying out Noah's (@noaheverett) TwitPic @twitpic...., Sentiment: 0.00
# 🔹 Starting real-time sentiment analysis simulation...🔹 Starting real-time sentiment analysis simulation...
#
# 📢 Tweet 1: @stephenfry Dude, you're down wid da kids.  Or som..., Sentiment: 0.00
# 📢 Tweet 1: @gumberries wheres the link?  oh i see..lemesee ..., Sentiment: 0.00
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: @InsidePorn aw, you're such a sweetheart!  You're ..., Sentiment: 0.82
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: @KrisAllenFans How about all of the above...LOL ..., Sentiment: 0.00
# 🔹 Starting real-time sentiment analysis simulation...
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: @gandmetz what's the radio frequency of radio one?..., Sentiment: 0.00📢 Tweet 1: I've been up for 40 hours thus far.  Mmm, Monster...., Sentiment: -0.65
# 🔹 Starting real-time sentiment analysis simulation...
#
# 📢 Tweet 1: @laur945 Thanks m'dear! I'll need it. I particular..., Sentiment: -0.22
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: @FranAnnie *hugs* Don't leave! Bye ..., Sentiment: 0.11
# 🔹 Starting real-time sentiment analysis simulation...
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: @bangbrenda the weirdest dreaam !  you don't need ..., Sentiment: 0.38
# 📢 Tweet 1: @mike_salvatore Yeah ..., Sentiment: 0.30
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: @shelikescute that's so sad ..., Sentiment: -0.61
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: Going to the gym...... yuck ..., Sentiment: 0.00
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: Getting ready to spend a day in the great outdoors..., Sentiment: 0.77
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: @JudithandJim sounds right up my alley...unfortuna..., Sentiment: 0.10
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: Have to go offline , GOOD NIGHT ..., Sentiment: 0.48
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: @Dominiricanbayb hmmmm u didn't answer the questio..., Sentiment: 0.00
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: Ladies and Gentlemen @sweet_charlotte and I have a..., Sentiment: 0.00
# 🔹 Starting real-time sentiment analysis simulation...
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: @firefaunx tooo much hate among us ..., Sentiment: -0.57
# 📢 Tweet 1: Liking &quot;karena dia&quot; by the banery ..., Sentiment: 0.40
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: Heyyy!!! photoshoop taday with _________jjijiji   ..., Sentiment: 0.84
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: @Neda You poor, poor girl...   So unfair..., Sentiment: -0.86
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: #iranelection makes me sad  see i do gotta heart!..., Sentiment: -0.53
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: Another Sunday, day of rest, my a...! Not with a b..., Sentiment: 0.72
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: @wxnerd4 I am a fan of Culver's custard. YUMMY!! ..., Sentiment: 0.79
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: Not feeling good... Hate it when he's gone ..., Sentiment: 0.39
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: Wanna watch &quot;UP&quot; but it's still in AUGUS..., Sentiment: -0.54
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: The best things in life..aren't things. ..., Sentiment: 0.64
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: @flipflops hah thanks, I wish I knew all that befo..., Sentiment: 0.80
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: Hiccups are back... ..., Sentiment: 0.00
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: How can one person go from the best day in a long ..., Sentiment: 0.03
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: Feel my confidence and level of honesty is increas..., Sentiment: 0.66
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: @delanogj3 LOL yeah yours sound better than mine. ..., Sentiment: 0.82
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: @durtymo nothing much! getting ready to enjoy the ..., Sentiment: 0.78
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: @nycjenny lack of sleep affects memory just about ..., Sentiment: -0.32
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: without you I've lost my way ..., Sentiment: 0.24
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: watching final fantasy XIII trailers... its  blood..., Sentiment: 0.30
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: @joshgroban Ed McMahon died?! That's horrible ..., Sentiment: -0.58
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: @PregnantBirds i just had a layover in charlotte  ..., Sentiment: 0.00
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: Thank you for all the happy birthday wishes! I am ..., Sentiment: 0.96
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: @Lish95 Wanna talk about it ? ..., Sentiment: 0.00
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: finally resting after driving 45min for a &quot;tr..., Sentiment: 0.00
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: Wishes I could read something interesting right no..., Sentiment: 0.28
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: Bye bye Magics ... Sorry, Dwight!   ---  2-0..., Sentiment: -0.15
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: at work ..., Sentiment: 0.00
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: Thanks to those of you who offered to make a logo ..., Sentiment: 0.68
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: thinks nosedives are pretty scary ..., Sentiment: 0.00
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: @mrgono3 haha it's late buuut no more chamber.. No..., Sentiment: -0.17
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: @jennettemccurdy my ipod's still not charging and ..., Sentiment: -0.22
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: Boring esok dh isnin ..., Sentiment: -0.32
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: @mileysupportrs1 I think she feeling  because she ..., Sentiment: 0.13
# 🔹 Starting real-time sentiment analysis simulation...
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: Ohh i forgot to tell you last night that when i wa..., Sentiment: 0.72
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: Breaks with key four is torture......no one plays ..., Sentiment: 0.59
# 📢 Tweet 1: is pretty sure she has a staph infection. Sonofabi..., Sentiment: 0.80
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: @Brandon_E  they don't....not to ruin your #incubu..., Sentiment: 0.47
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: Tuesday's sweet-tweet: Get $1 off your purchase of..., Sentiment: 0.49
# 🔹 Starting real-time sentiment analysis simulation...
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: im eating a chocolate crakle. i bet you all are je..., Sentiment: 0.40
# 📢 Tweet 1: @zelciia oh hey ... i remember making that when i ..., Sentiment: 0.00
# 🔹 Starting real-time sentiment analysis simulation...
# 📢 Tweet 1: @iheartnewyork    sorry k!..., Sentiment: -0.15
